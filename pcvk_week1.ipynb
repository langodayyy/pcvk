# %% [markdown]
# <a href="https://colab.research.google.com/github/langodayyy/pcvk/blob/main/pcvk_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTetozNGSvzTy9tcuPnpnzBytkc717a1OWlsQ&s",
        "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSM7fch9TlfGiU8xn7yrvI4AmfV5zSI-ry1bg&s",
        "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSp2GD53JwF6VDMrcnLzr4yvBGNTXOeidoT9w&s"]

#loop image
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to rgb
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)                           #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=274x92>
# <PIL.Image.Image image mode=RGB size=260x97>
# <PIL.Image.Image image mode=RGB size=300x84>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ", tinggi," x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  84  x  150
# <PIL.Image.Image image mode=RGB size=150x84>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab? <br>
# ```jawaban:``` hal ini dikarenakan Google Colab merupakan teks editor berbasis web, sehingga dapat diakses dari mana saja tanpa perlu menginstal software tambahan di komputer pengguna.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini? <br>
# ```jawaban:``` <br> -NumPy (import numpy as np): Digunakan untuk komputasi numerik dan manipulasi array multidimensi dengan efisien.<br> -Pandas (import pandas as pd): Digunakan untuk analisis dan manipulasi data, terutama dalam format tabel menggunakan DataFrame.<br> -OpenCV (import cv2 as cv): Digunakan untuk pemrosesan gambar dan video serta aplikasi visi komputer.<br> -Google Colab Patches (from google.colab.patches import cv2_imshow): Digunakan untuk menampilkan gambar dengan OpenCV di Google Colab.<br> -Scikit-Image (from skimage import io): Digunakan untuk membaca dan menulis gambar serta melakukan pemrosesan gambar.<br> -Scikit-Image Transform (from skimage import transform): Digunakan untuk transformasi geometris pada gambar seperti rotasi dan penskalaan.<br> -Pillow (PIL) (from PIL import Image): Digunakan untuk membuka, memanipulasi, dan menyimpan gambar dalam berbagai format.<br> -Matplotlib (import matplotlib.pylab as plt): Digunakan untuk membuat grafik dan visualisasi data, termasuk menampilkan gambar.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut : <br>
# ```image = cv.resize(image, (0,0), fx=0.5, y=0.5``` <br>
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?
# <br>```jawaban:``` potongan kode program tersebut digunakan untuk memperkecil ukuran dari gambar. jika potongan kode program tersebut tidak digunakan maka saat dijalankan sistem akan menampilkan ukuran gambar yang sebenarnya
#
# 4. perhatikan potongan kode program berikut: <br>
# ```#membuat garis horizontal ditengah image``` <br>
# ```for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]``` <br>
# apakah kegunaan kode [255,255,255]? jelaskan! <br>
# ```jawaban:``` kode [255,255,255] merupakan repsentasi dari warna red, green, blue (RGB) hal ini digunakan untuk menambahkan warna pada garis horizontal yang terletak di tengah gambar. kode RGB bisa diubah sesuai dengan kemauan
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah! <br>
# ```jawaban:```
# piksel adalah unit dasar yang membentuk gambar digital, dan resolusi menentukan jumlah piksel dalam suatu gambar. Resolusi yang lebih tinggi menghasilkan gambar yang lebih rinci dan tajam, sedangkan resolusi yang lebih rendah dapat menghasilkan gambar yang lebih kasar atau kurang jelas.

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for x in range(tinggi):
    image_3[x, int((lebar) / 2)] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis vertikal ditengah image
for x in range(tinggi):
    #dari kiri ke kanan
    image_3[x, int((lebar/tinggi)*x)] = [255, 255, 255]
    #dari kanan ke kiri
    image_3[x, int((lebar/tinggi)*(tinggi-x-1))] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tentukan panjang garis
panjang_garis = 40

start_x = (lebar - panjang_garis) // 2
end_x = start_x + panjang_garis

for y in range(start_x, end_x):
    image_3[int(tinggi / 2), y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat persegi disembarang tempat
position = [20, 30]
width = 35
for x in range (width):
  for y in range(width):
    image_3[position[0]+x, position[1]+y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=300x84>

# %% [markdown]
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
# <br>
# ```jawaban:```
# hal ini dikarenakan matplotlib selalu mengonversi hasil outputnya sedangkan opencv tidak
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan. Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %%
path="ktp.jpg"
image = io.imread(path)                            #read image
image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
ktp = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to rgb
# cv2_imshow(image_2)                           #show image
print('\n')


nik=[75,143,30,250]

for x in range (nik[2]):
  for y in range(nik[3]):
    ktp[nik[0]+x, nik[1]+y] = [255,187,1]

nama=[114,150,13,90]

for x in range (nama[2]):
  for y in range(nama[3]):
    ktp[nama[0]+x, nama[1]+y] = [114,150,90]

#final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(ktp)
ktp = cv.cvtColor(ktp, cv.COLOR_RGB2BGR)
plt.imshow(ktp)
# Out:
# <PIL.Image.Image image mode=RGB size=600x386>

# %%
# !jupyter nbconvert --to html /content/pcvk_week1.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/pcvk_week1.ipynb to html
# [NbConvertApp] Writing 1947285 bytes to /content/pcvk_week1.html
